# %%
import pandas as pd

# %%
pop_change = pd.read_csv('pop_change.csv')
pop_change.head()
# Out:
#   # POPULATION CHANGE DATA PROVIDED BY U.S. CENSUS.       Unnamed: 1  \
# 0         # CHANGE EXPRESSED AS PERCENTAGE (0-100).              NaN
# 1                                   STATE_OR_REGION  1910_POPULATION
# 2                                     United States         92228531
# 3                                         Northeast         25868573
# 4                                           Midwest         29888542
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0              NaN              NaN              NaN              NaN
# 1  1920_POPULATION  1930_POPULATION  1940_POPULATION  1950_POPULATION
# 2        106021568        123202660        132165129        151325798
# 3         29662053         34427091         35976777         39477986
# 4         34019792         38594100         40143332         44460762
#
#         Unnamed: 6       Unnamed: 7       Unnamed: 8       Unnamed: 9  \
# ...

# %%
pop_change.drop(pop_change.index[0])
pop_change.head()
# Out:
#   # POPULATION CHANGE DATA PROVIDED BY U.S. CENSUS.       Unnamed: 1  \
# 0         # CHANGE EXPRESSED AS PERCENTAGE (0-100).              NaN
# 1                                   STATE_OR_REGION  1910_POPULATION
# 2                                     United States         92228531
# 3                                         Northeast         25868573
# 4                                           Midwest         29888542
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0              NaN              NaN              NaN              NaN
# 1  1920_POPULATION  1930_POPULATION  1940_POPULATION  1950_POPULATION
# 2        106021568        123202660        132165129        151325798
# 3         29662053         34427091         35976777         39477986
# 4         34019792         38594100         40143332         44460762
#
#         Unnamed: 6       Unnamed: 7       Unnamed: 8       Unnamed: 9  \
# ...

# %%
pop_change = pop_change.iloc[1:]
pop_change.head()
# Out:
#   # POPULATION CHANGE DATA PROVIDED BY U.S. CENSUS.       Unnamed: 1  \
# 1                                   STATE_OR_REGION  1910_POPULATION
# 2                                     United States         92228531
# 3                                         Northeast         25868573
# 4                                           Midwest         29888542
# 5                                             South         29389330
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 1  1920_POPULATION  1930_POPULATION  1940_POPULATION  1950_POPULATION
# 2        106021568        123202660        132165129        151325798
# 3         29662053         34427091         35976777         39477986
# 4         34019792         38594100         40143332         44460762
# 5         33125803         37857633         41665901         47197088
#
#         Unnamed: 6       Unnamed: 7       Unnamed: 8       Unnamed: 9  \
# ...

# %%
pop_change.columns = pop_change.iloc[0].values
pop_change = pop_change.iloc[1:]

# %%
pop_change.head()
# Out:
#   STATE_OR_REGION 1910_POPULATION 1920_POPULATION 1930_POPULATION  \
# 2   United States        92228531       106021568       123202660
# 3       Northeast        25868573        29662053        34427091
# 4         Midwest        29888542        34019792        38594100
# 5           South        29389330        33125803        37857633
# 6            West         7082086         9213920        12323836
#
#   1940_POPULATION 1950_POPULATION 1960_POPULATION 1970_POPULATION  \
# 2       132165129       151325798       179323175       203211926
# 3        35976777        39477986        44677819        49040703
# 4        40143332        44460762        51619139        56571663
# 5        41665901        47197088        54973113        62795367
# 6        14379119        20189962        28053104        34804193
#
#   1980_POPULATION 1990_POPULATION     ...     1920_CHANGE 1930_CHANGE  \
# 2       226545805       248709873     ...              15        16.2
# ...
